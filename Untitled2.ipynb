# %%
from tkinter import *
import math,random

LARGEUR = 480
HAUTEUR = 320
RAYON = 5 # rayon de la balle

# position initiale au milieu
X = LARGEUR/2
Y = HAUTEUR/2


# coord = {Balle:(X,Y)}
         

def effacer():
    Canevas.delete("all")
    
def deplacement():
        """ Déplacement de la balle """

        for k in range(0,len(Balle)):
            #coord.add
            
            global X,Y,DX,DY,RAYON,LARGEUR,HAUTEUR

            vitesse = random.uniform(1.8,2)*5
            angle = random.uniform(2*math.pi)
            DX = vitesse*math.cos(angle)
            DY = vitesse*math.sin(angle)


            # rebond à droite
            if X+RAYON+DX > LARGEUR:
                X = 2*(LARGEUR-RAYON)-X
                DX = -DX

            # rebond à gauche
            if X-RAYON+DX < 0:
                X = 2*RAYON-X
                DX = -DX

            # rebond en bas
            if Y+RAYON+DY > HAUTEUR:
                Y = 2*(HAUTEUR-RAYON)-Y
                DY = -DY

            # rebond en haut
            if Y-RAYON+DY < 0:
                Y = 2*RAYON-Y
                DY = -DY

            X = X+DX
            Y = Y+DY

            # affichage
            Canevas.coords(Balle[k],X-RAYON,Y-RAYON,X+RAYON,Y+RAYON)
        if Arret == False:

            # mise à jour toutes les 50 ms
            Mafenetre.after(50,deplacement)
    
def Arreter():
        """ Arrêt de l'animation """
        global Arret

        Arret = True
        Balle[:] = []

def Demarrer():
        """ Démarre l'animation """
        effacer()
        global Arret
        l=0
        j = int(Valeur.get())
        if Arret == True:
            if j != l:
                for i in range (0,j):
                    Balle.append(Canevas.create_oval(X1-RAYON,Y1-RAYON,X1+RAYON,Y1+RAYON,width=1,fill='green'))
                l = j

            Arret = False
            deplacement()# un seul appel à cette fonction
    
Arret = True
        
# Création de la fenêtre principale
Mafenetre = Tk()
Mafenetre.title("Animation Balle")

# Création d'un widget Canvas
Canevas = Canvas(Mafenetre,height=HAUTEUR,width=LARGEUR,bg='white')
Canevas.pack(padx=5,pady=5)

# Création d'un widget Button (bouton Démarrer)
BoutonGo = Button(Mafenetre, text ='Démarrer', command = Demarrer)
BoutonGo.pack(side = LEFT, padx = 10, pady = 10)

# Création d'un widget Button (bouton Arrêter)
BoutonArreter = Button(Mafenetre, text ='Arrêter', command = Arreter)
BoutonArreter.pack(side = LEFT, padx = 5, pady = 5)

Valeur = StringVar()
Valeur.set(1)
# Création d'un widget Spinbox
boite = Spinbox(Mafenetre,from_=1,to=300,increment=1,textvariable=Valeur,width=5)
boite.pack(padx=30,pady=10)

# Création d'un objet graphique
Balle=[]

print("fghghfhgf")
# deplacement()
Mafenetre.mainloop()
# Out:
# fghghfhgf
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "<ipython-input-32-7bbf2fc7ad89>", line 83, in Demarrer
#     deplacement()# un seul appel à cette fonction
#   File "<ipython-input-32-7bbf2fc7ad89>", line 28, in deplacement
#     angle = random.uniform(2*math.pi)
# TypeError: uniform() missing 1 required positional argument: 'b'

# %%
from tkinter import *
import math,random

LARGEUR = 480
HAUTEUR = 320
RAYON = 5 # rayon de la balle

# position initiale au milieu
X = LARGEUR/2
Y = HAUTEUR/2


def effacer():
    print("dans effacer")
    Canevas.delete("all")
        
def deplacement():
    """ Déplacement de la balle """
    print("deplacement")

    for k in range(0,len(Balle)):
        
        global X,Y#,DX,DY,RAYON,LARGEUR,HAUTEUR
    
        vitesse = random.uniform(1.8,2)*5
        angle = random.uniform(0,2*math.pi)
        DX = vitesse*math.cos(angle)
        DY = vitesse*math.sin(angle)
    
    
        # rebond à droite
        if X+RAYON+DX > LARGEUR:
            X = 2*(LARGEUR-RAYON)-X
            DX = -DX
    
        # rebond à gauche
        if X-RAYON+DX < 0:
            X = 2*RAYON-X
            DX = -DX
    
        # rebond en bas
        if Y+RAYON+DY > HAUTEUR:
            Y = 2*(HAUTEUR-RAYON)-Y
            DY = -DY
        
        # rebond en haut
        if Y-RAYON+DY < 0:
            Y = 2*RAYON-Y
            DY = -DY
    
        X = X+DX
        Y = Y+DY
    
        # affichage
        Canevas.coords(Balle[k],X-RAYON,Y-RAYON,X+RAYON,Y+RAYON)
    if Arret == False:

        # mise à jour toutes les 50 ms
        Mafenetre.after(50,deplacement)
    
def Arreter():
    """ Arrêt de l'animation """
    global Arret
    print("Arreter")
    Arret = True
    Balle[:] = []

def Demarrer():
    """ Démarre l'animation """
    effacer()
    global Arret
    l=0
    j = int(Valeur.get())
    if Arret == True:
        if j != l:
        
            for i in range (0,j):   
                Balle.append(Canevas.create_oval(X-RAYON,Y-RAYON,X+RAYON,Y+RAYON,width=1,fill='green'))
            l = j
            
        Arret = False
        deplacement()# un seul appel à cette fonction
    
              
               
    
        
Arret = True
        
# Création de la fenêtre principale
Mafenetre = Tk()
Mafenetre.title("Animation Balle")

# Création d'un widget Canvas
Canevas = Canvas(Mafenetre,height=HAUTEUR,width=LARGEUR,bg='white')
Canevas.pack(padx=5,pady=5)

# Création d'un widget Button (bouton Démarrer)
BoutonGo = Button(Mafenetre, text ='Démarrer', command = Demarrer)
BoutonGo.pack(side = LEFT, padx = 10, pady = 10)

# Création d'un widget Button (bouton Arrêter)
BoutonArreter = Button(Mafenetre, text ='Arrêter', command = Arreter)
BoutonArreter.pack(side = LEFT, padx = 5, pady = 5)

Valeur = StringVar()
Valeur.set(1)
# Création d'un widget Spinbox
boite = Spinbox(Mafenetre,from_=1,to=300,increment=1,textvariable=Valeur,width=5)
boite.pack(padx=30,pady=10)

# Création d'un objet graphique
Balle=[]


Mafenetre.mainloop()
# Out:
# dans effacer
# deplacement
# deplacement
# deplacement
# deplacement
# deplacement
# deplacement
# deplacement
# deplacement
# deplacement
# deplacement
# deplacement
# deplacement
# deplacement
# deplacement
# deplacement
# deplacement
# deplacement
# deplacement
# deplacement
# deplacement
# deplacement
# deplacement
# deplacement
# deplacement
# deplacement
# deplacement
# deplacement
# deplacement
# deplacement
# deplacement
# deplacement
# deplacement
# deplacement
# deplacement
# deplacement
# deplacement
# deplacement
# deplacement
# deplacement
# deplacement
# deplacement
# deplacement
# deplacement
# deplacement
# deplacement
# deplacement
# deplacement
# deplacement
# deplacement
# deplacement
# deplacement
# deplacement
# deplacement
# deplacement

# %%
from tkinter import *
import math,random

LARGEUR = 480
HAUTEUR = 320
RAYON = 5 # rayon de la balle

n = int(Valeur.get())

# position initiale au milieu
X = []
Y = []
for i in range(n):
    #Si toutes les boules au milieu au démarrage, enlever le multipli.
    X.append(0)#LARGEUR*random.uniform(0.1,0.9))
    Y.append(0)#HAUTEUR*random.uniform(0.1,0.9))
    
# direction initiale aleatoire
DX = []
DY = []    
for i in range(n):
    vitesse = random.uniform(1.8,2)*5
    angle = random.uniform(0,2*math.pi)
    DX.append(vitesse*math.cos(angle))
    DY.append(vitesse*math.sin(angle))

def effacer():
    # print("dans effacer")
    Canevas.delete("all")
        
def deplacement():
    """ Déplacement de la balle """
    # print("deplacement")
    global X,Y,DX,DY,RAYON,LARGEUR,HAUTEUR

    for i in range(n):
        # rebond a droite
        if X[i]+RAYON+DX[i] > LARGEUR:
            X[i] = 2*(LARGEUR-RAYON)-X[i]
            DX[i] = -DX[i]
   
        # rebond a gauche
        if X[i]-RAYON+DX[i] < 0:
            X[i] = 2*RAYON-X[i]
            DX[i] = -DX[i]
    
        # rebond en bas
        if Y[i]+RAYON+DY[i] > HAUTEUR:
            Y[i] = 2*(HAUTEUR-RAYON)-Y[i]
            DY[i] = -DY[i]

        # rebond en haut
        if Y[i]-RAYON+DY[i] < 0:
            Y[i] = 2*RAYON-Y[i]
            DY[i] = -DY[i]
    
        X[i] = X[i]+DX[i]
        Y[i] = Y[i]+DY[i]
    
        # affichage
        Canevas.coords(Balle[i],X[i]-RAYON,Y[i]-RAYON,X[i]+RAYON,Y[i]+RAYON)
    if Arret == False:

        # mise à jour toutes les 50 ms
        Mafenetre.after(50,deplacement)
    
def Arreter():
    """ Arrêt de l'animation """
    global Arret
    print("Arreter")
    Arret = True
    Balle[:] = []

def Demarrer():
    """ Démarre l'animation """
    effacer()
    '''global Arret
    l=0
    j = int(Valeur.get())
    if Arret == True:
        if j != l:
            for i in range(n):
                
                Balle.append(Canevas.create_oval(X[i]-RAYON,Y[i]-RAYON,X[i]+RAYON,Y[i]+RAYON,width=1,fill='green'))
                l = j
            
                Arret = False
                deplacement()# un seul appel à cette fonction''' #A refaire
    
              
               
    
        
Arret = True


# Création de la fenêtre principale
Mafenetre = Tk()
Mafenetre.title("Animation Balle")

# Création d'un widget Canvas
Canevas = Canvas(Mafenetre,height=HAUTEUR,width=LARGEUR,bg='white')
Canevas.pack(padx=5,pady=5)

# Création d'un widget Button (bouton Démarrer)
BoutonGo = Button(Mafenetre, text ='Démarrer', command = Demarrer)
BoutonGo.pack(side = LEFT, padx = 10, pady = 10)

# Création d'un widget Button (bouton Arrêter)
BoutonArreter = Button(Mafenetre, text ='Arrêter', command = Arreter)
BoutonArreter.pack(side = LEFT, padx = 5, pady = 5)

Valeur = StringVar()
Valeur.set(1)
# Création d'un widget Spinbox
boite = Spinbox(Mafenetre,from_=1,to=300,increment=1,textvariable=Valeur,width=5)
boite.pack(padx=30,pady=10)

# Création d'un objet graphique
Balle=[]
for i in range(n):
    Balle.append(Canevas.create_oval(X[i]-RAYON,Y[i]-RAYON,X[i]+RAYON,Y[i]+RAYON,width=1,fill='green'))



Mafenetre.mainloop()
# Out:
# Arreter
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 608, in callit
#     func(*args)
#   File "<ipython-input-62-c687b72ee469>", line 61, in deplacement
#     Canevas.coords(Balle[i],X[i]-RAYON,Y[i]-RAYON,X[i]+RAYON,Y[i]+RAYON)
# IndexError: list index out of range
# Arreter
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 608, in callit
#     func(*args)
#   File "<ipython-input-62-c687b72ee469>", line 61, in deplacement
#     Canevas.coords(Balle[i],X[i]-RAYON,Y[i]-RAYON,X[i]+RAYON,Y[i]+RAYON)
# IndexError: list index out of range
# Arreter
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 608, in callit
#     func(*args)
#   File "<ipython-input-62-c687b72ee469>", line 61, in deplacement
#     Canevas.coords(Balle[i],X[i]-RAYON,Y[i]-RAYON,X[i]+RAYON,Y[i]+RAYON)
# IndexError: list index out of range
# Arreter
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 608, in callit
#     func(*args)
#   File "<ipython-input-62-c687b72ee469>", line 61, in deplacement
#     Canevas.coords(Balle[i],X[i]-RAYON,Y[i]-RAYON,X[i]+RAYON,Y[i]+RAYON)
# IndexError: list index out of range
# Arreter
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 1562, in __call__
#     return self.func(*args)
#   File "/usr/lib/python3.5/tkinter/__init__.py", line 608, in callit
#     func(*args)
#   File "<ipython-input-62-c687b72ee469>", line 61, in deplacement
#     Canevas.coords(Balle[i],X[i]-RAYON,Y[i]-RAYON,X[i]+RAYON,Y[i]+RAYON)
# IndexError: list index out of range
